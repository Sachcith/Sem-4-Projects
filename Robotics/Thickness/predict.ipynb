# %%
import joblib
from audio_related import extract_features

model = joblib.load("thickness_model_rfr_ms.pkl")
scaler = joblib.load("scaler_rfr.pkl")


def predict_thickness(audio_path):

    features = extract_features(audio_path)

    features = scaler.transform([features])

    prediction = model.predict(features)[0]

    return prediction


def predict_folder(folder_path):

    for file in os.listdir(folder_path):

        if not file.endswith(".wav"):
            continue

        file_path = os.path.join(folder_path, file)

        try:
            thickness = predict_thickness(file_path)

            print(file, "→ Predicted Thickness:", round(thickness, 3), "mm")

        except Exception as e:
            print("Error processing", file, ":", e)


folder_path = r"C:\Users\jashw\OneDrive\Desktop\Sem 4\Robotics\Project\train\thickness\data\mild stell testing\New folder"

predict_folder(folder_path)
# Out:
# audio_1772288167_3mm.wav → Predicted Thickness: 3.0 mm
# audio_1772288208_3mm.wav → Predicted Thickness: 2.91 mm
# audio_1772288261_3mm.wav → Predicted Thickness: 2.926 mm
# audio_1772288301_3mm.wav → Predicted Thickness: 2.94 mm
# audio_1772288353_3mm.wav → Predicted Thickness: 2.734 mm
# audio_1772353386_4mm.wav → Predicted Thickness: 3.876 mm
# audio_1772353433_4mm.wav → Predicted Thickness: 3.874 mm
# audio_1772353610_4mm.wav → Predicted Thickness: 3.836 mm
# audio_1772353659_4mm.wav → Predicted Thickness: 3.002 mm
# audio_1772353698_4mm.wav → Predicted Thickness: 3.83 mm
# audio_1772980799_1mm.wav → Predicted Thickness: 1.686 mm
# audio_1772980842_1mm.wav → Predicted Thickness: 1.0 mm
# audio_1772980887_1mm.wav → Predicted Thickness: 1.032 mm
# audio_1772980927_1mm.wav → Predicted Thickness: 1.042 mm
# audio_1772980971_1mm.wav → Predicted Thickness: 2.998 mm

# %%
import joblib
from audio_related import extract_features

model = joblib.load("thickness_model_svm.pkl")
scaler = joblib.load("scaler_svm.pkl")


def predict_thickness(audio_path):

    features = extract_features(audio_path)

    features = scaler.transform([features])

    prediction = model.predict(features)[0]

    return prediction


def predict_folder(folder_path):

    for file in os.listdir(folder_path):

        if not file.endswith(".wav"):
            continue

        file_path = os.path.join(folder_path, file)

        try:
            thickness = predict_thickness(file_path)

            print(file, "→ Predicted Thickness:", round(thickness, 3), "mm")

        except Exception as e:
            print("Error processing", file, ":", e)


folder_path = r"C:\Users\jashw\OneDrive\Desktop\Sem 4\Robotics\Project\train\thickness\data\mild stell testing\New folder"

predict_folder(folder_path)
# Out:
# audio_1772288167_3mm.wav → Predicted Thickness: 3.108 mm
# audio_1772288208_3mm.wav → Predicted Thickness: 2.895 mm
# audio_1772288261_3mm.wav → Predicted Thickness: 2.976 mm
# audio_1772288301_3mm.wav → Predicted Thickness: 3.057 mm
# audio_1772288353_3mm.wav → Predicted Thickness: 2.897 mm
# audio_1772353386_4mm.wav → Predicted Thickness: 3.932 mm
# audio_1772353433_4mm.wav → Predicted Thickness: 3.343 mm
# audio_1772353610_4mm.wav → Predicted Thickness: 2.963 mm
# audio_1772353659_4mm.wav → Predicted Thickness: 2.577 mm
# audio_1772353698_4mm.wav → Predicted Thickness: 3.421 mm
# audio_1772980799_1mm.wav → Predicted Thickness: 1.035 mm
# audio_1772980842_1mm.wav → Predicted Thickness: 0.724 mm
# audio_1772980887_1mm.wav → Predicted Thickness: 0.961 mm
# audio_1772980927_1mm.wav → Predicted Thickness: 0.965 mm
# audio_1772980971_1mm.wav → Predicted Thickness: 2.452 mm

# %% [markdown]
# def predict_thickness(audio_path):
#
#     features = extract_features(audio_path)
#
#     features = scaler.transform([features])
#
#     prediction = model.predict(features)[0]
#
#     return prediction
#
# audio_file = r"C:\Users\jashw\OneDrive\Desktop\Sem 4\Robotics\Project\train\thickness\data\mild stell testing\m_t3\audio_1772353386.wav"
# # audio_file = r"C:\Users\jashw\OneDrive\Desktop\Sem 4\Robotics\Project\train\thickness\data\mild stell testing\m_t2\audio_1772288167.wav"
#
# # k = audio_file = r"C:\Users\jashw\OneDrive\Desktop\Sem 4\Robotics\Project\train\thickness\data\mild stell testing\m_t2"
# # print(len(k))
#
# thickness = predict_thickness(audio_file)
#
# print("Predicted Thickness:", round(thickness, 3), "mm")

# %%
import joblib
from audio_related import extract_features

model = joblib.load("thickness_model_xg.pkl")
scaler = joblib.load("scaler_xg.pkl")


def predict_thickness(audio_path):

    features = extract_features(audio_path)

    features = scaler.transform([features])

    prediction = model.predict(features)[0]

    return prediction


def predict_folder(folder_path):

    for file in os.listdir(folder_path):

        if not file.endswith(".wav"):
            continue

        file_path = os.path.join(folder_path, file)

        try:
            thickness = predict_thickness(file_path)

            print(file, "→ Predicted Thickness:", round(thickness, 3), "mm")

        except Exception as e:
            print("Error processing", file, ":", e)


folder_path = r"C:\Users\jashw\OneDrive\Desktop\Sem 4\Robotics\Project\train\thickness\data\mild stell testing\New folder"

predict_folder(folder_path)
# Out:
# audio_1772288167_3mm.wav → Predicted Thickness: 3.0 mm
# audio_1772288208_3mm.wav → Predicted Thickness: 3.0 mm
# audio_1772288261_3mm.wav → Predicted Thickness: 2.97 mm
# audio_1772288301_3mm.wav → Predicted Thickness: 3.029 mm
# audio_1772288353_3mm.wav → Predicted Thickness: 2.993 mm
# audio_1772353386_4mm.wav → Predicted Thickness: 4.027 mm
# audio_1772353433_4mm.wav → Predicted Thickness: 4.022 mm
# audio_1772353610_4mm.wav → Predicted Thickness: 4.007 mm
# audio_1772353659_4mm.wav → Predicted Thickness: 1.962 mm
# audio_1772353698_4mm.wav → Predicted Thickness: 4.028 mm
# audio_1772980799_1mm.wav → Predicted Thickness: 2.897 mm
# audio_1772980842_1mm.wav → Predicted Thickness: 0.999 mm
# audio_1772980887_1mm.wav → Predicted Thickness: 1.0 mm
# audio_1772980927_1mm.wav → Predicted Thickness: 1.06 mm
# audio_1772980971_1mm.wav → Predicted Thickness: 1.949 mm

# %%
import joblib
from audio_related import extract_features

model = joblib.load("thickness_model_gboost.pkl")
scaler = joblib.load("scaler_gboost.pkl")


def predict_thickness(audio_path):

    features = extract_features(audio_path)

    features = scaler.transform([features])

    prediction = model.predict(features)[0]

    return prediction


def predict_folder(folder_path):

    for file in os.listdir(folder_path):

        if not file.endswith(".wav"):
            continue

        file_path = os.path.join(folder_path, file)

        try:
            thickness = predict_thickness(file_path)

            print(file, "→ Predicted Thickness:", round(thickness, 3), "mm")

        except Exception as e:
            print("Error processing", file, ":", e)


folder_path = r"C:\Users\jashw\OneDrive\Desktop\Sem 4\Robotics\Project\train\thickness\data\mild stell testing\New folder"

predict_folder(folder_path)
# Out:
# audio_1772288167_3mm.wav → Predicted Thickness: 2.998 mm
# audio_1772288208_3mm.wav → Predicted Thickness: 2.945 mm
# audio_1772288261_3mm.wav → Predicted Thickness: 2.917 mm
# audio_1772288301_3mm.wav → Predicted Thickness: 2.916 mm
# audio_1772288353_3mm.wav → Predicted Thickness: 2.685 mm
# audio_1772353386_4mm.wav → Predicted Thickness: 3.996 mm
# audio_1772353433_4mm.wav → Predicted Thickness: 3.929 mm
# audio_1772353610_4mm.wav → Predicted Thickness: 4.001 mm
# audio_1772353659_4mm.wav → Predicted Thickness: 2.536 mm
# audio_1772353698_4mm.wav → Predicted Thickness: 4.075 mm
# audio_1772980799_1mm.wav → Predicted Thickness: 1.986 mm
# audio_1772980842_1mm.wav → Predicted Thickness: 1.049 mm
# audio_1772980887_1mm.wav → Predicted Thickness: 1.002 mm
# audio_1772980927_1mm.wav → Predicted Thickness: 1.47 mm
# audio_1772980971_1mm.wav → Predicted Thickness: 2.549 mm
